# %% [markdown]
# # XIST Quantitative Visualization

# %%
import numpy as np

import numba
import pandas

import skimage
import skimage.io
import skimage.filters
import skimage.segmentation
import skimage.measure
import skimage.morphology
import skimage.feature
import bi1x

import imageio

import os
import colorcet

import bokeh.io
import bokeh.plotting
import bokeh.palettes as bp
import bokeh.models

bokeh.io.output_notebook()

notebook_url = 'localhost:8888'

import max_int_projection
import auto_segmentation
import applying_man_seg
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
area_cutoff = ['manual', '.05', '.06', '.065', '.07']
cell_counts = [50, 54, 52, 51, 48]

p = bokeh.plotting.figure(x_range=area_cutoff, 
                    plot_height=400, 
                    plot_width=800,
                    title='Number of XIST Positive Cells')

p.vbar(x=area_cutoff, top=cell_counts, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="1c049b3b-db03-4f52-8c7b-db6831bf31a1" data-root-id="1129"></div>

# %%
area_cutoff = ['manual', '.05', '.06', '.065', '.07']
cell_counts = [20, 16, 18, 19, 22]

p = bokeh.plotting.figure(x_range=area_cutoff, 
                    plot_height=400, 
                    plot_width=800,
                    title='Number of XIST Negative Cells')

p.vbar(x=area_cutoff, top=cell_counts, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="faf65f9b-3c8c-47e0-981b-233ede71fe2d" data-root-id="1456"></div>

# %%
area_cutoff = ['manual', '.05', '.06', '.065', '.07']
cell_counts = [100, 94.3, 97.1, 98.6, 97.1]

p = bokeh.plotting.figure(x_range=area_cutoff, 
                    plot_height=400, 
                    plot_width=800,
                    title='% Accuracy')

p.vbar(x=area_cutoff, top=cell_counts, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="7e2b154a-e1d0-49be-ae24-9f45c67a64c3" data-root-id="1339"></div>
